# %% [markdown]
# # Round 2

# %% [markdown]
# Imported libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 1. Reading the file

# %%
file1 = pd.read_csv('marketing_customer_analysis.csv') # Reading the dataframe
file1 = file1.drop(['Unnamed: 0'], axis=1) # droping the auromatically created index column
display(file1)
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %% [markdown]
# ### 2. Standardize header names.

# %%
cols = []
for column in file1.columns:
    cols.append(column.lower())
cols
file1.columns = cols
file1.head()
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  DK49336     Arizona              4809.216960       No     Basic   College
# 1  KX64629  California              2228.525238       No     Basic   College
# 2  LZ68649  Washington             14947.917300       No     Basic  Bachelor
# 3  XL78013      Oregon             22332.439460      Yes  Extended   College
# 4  QA50777      Oregon              9025.067525       No   Premium  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/18/11         Employed      M   48029  ...
# 1           1/18/11       Unemployed      F       0  ...
# 2           2/10/11         Employed      M   22139  ...
# 3           1/11/11         Employed      M   49078  ...
# 4           1/17/11    Medical Leave      F   23675  ...
#
#   number of open complaints number of policies     policy type        policy  \
# 0                       0.0                  9  Corporate Auto  Corporate L3
# ...

# %%
#Display the shape of the dataframe
file1.shape
# Out:
# (10910, 25)

# %%
# Displaying the columns that are numerical
file1.select_dtypes(include=np.number)
# Out:
#        customer lifetime value  income  monthly premium auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        months since last claim  months since policy inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
# Displaying the columns that are categorical
file1.select_dtypes(include=object)
# Out:
#       customer       state response  coverage education effective to date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       employmentstatus gender location code marital status     policy type  \
# ...

# %% [markdown]
# ### 5. Data cleaning

# %%
#Checking the % of nill values in the columns
nulls_df = pd.DataFrame(round(file1.isna().sum()/len(file1),4)*100)
nulls_df
nulls_df = nulls_df.reset_index()
nulls_df
nulls_df.columns = ['header_name', 'percent_nulls']
nulls_df
# Out:
#                       header_name  percent_nulls
# 0                        customer           0.00
# 1                           state           5.78
# 2         customer lifetime value           0.00
# 3                        response           5.78
# 4                        coverage           0.00
# 5                       education           0.00
# 6               effective to date           0.00
# 7                employmentstatus           0.00
# 8                          gender           0.00
# 9                          income           0.00
# 10                  location code           0.00
# 11                 marital status           0.00
# 12           monthly premium auto           0.00
# 13        months since last claim           5.80
# 14  months since policy inception           0.00
# 15      number of open complaints           5.80
# 16             number of policies           0.00
# 17                    policy type           0.00
# ...

# %% [markdown]
# #### Cleaning NaN values in "state" column

# %%
#Checking unique values (including NaNs) in the column and identifing the most common value for "state"
file1['state'].value_counts(dropna=False)
# Out:
# California    3552
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# NaN            631
# Name: state, dtype: int64

# %% [markdown]
# As value_counts() shows, all values in the state column are unique, and California is the most frequent value for the column. Therefore it is decided to replace the values of Nan with "California".

# %%
# Replacing the value
file1['state'] = file1['state'].fillna('California') 
# Checking the outcome
file1['state'].value_counts(dropna=False)
# Out:
# California    4183
# Oregon        2909
# Arizona       1937
# Nevada         993
# Washington     888
# Name: state, dtype: int64

# %% [markdown]
# #### Cleaning NaN values in "response" column

# %%
#Checking unique values (including NaNs) in the column and identifing the most common value for "response"
file1['response'].value_counts(dropna=False)
# Out:
# No     8813
# Yes    1466
# NaN     631
# Name: response, dtype: int64

# %% [markdown]
# Since the value "No" is the most common value and its number is significantly higher than the value "Yes", to minimise the inaccuracy of the data, we will substitute NaN values with the most common value ("No").

# %%
file1['response'] = file1['response'].fillna('No') 
file1['response'].value_counts(dropna=False)
# Out:
# No     9444
# Yes    1466
# Name: response, dtype: int64

# %% [markdown]
# #### Cleaning NaN values for "months since last claim" column

# %%
file1['months since last claim'].value_counts(dropna=False)
# Out:
# NaN     633
# 3.0     426
# 6.0     394
# 1.0     386
# 7.0     378
# 4.0     373
# 2.0     368
# 5.0     355
# 0.0     354
# 10.0    346
# 16.0    333
# 11.0    331
# 15.0    323
# 13.0    320
# 8.0     315
# 12.0    307
# 17.0    299
# 14.0    299
# 9.0     277
# 19.0    276
# 23.0    276
# 25.0    269
# 21.0    267
# 18.0    257
# 20.0    254
# 22.0    246
# 24.0    237
# 29.0    234
# 28.0    227
# 31.0    221
# 26.0    211
# 27.0    208
# 30.0    201
# 34.0    199
# 33.0    198
# 35.0    157
# 32.0    155
# Name: months since last claim, dtype: int64

# %% [markdown]
# Decision is to replace the NaN values with the mean value.

# %%
mean_months_since_last_claim = file1['months since last claim'].mean() 
file1['months since last claim'] = file1['months since last claim'].fillna(mean_months_since_last_claim)

# %%
file1['months since last claim'].isna().sum() #checking the outcome
# Out:
# 0

# %% [markdown]
# #### Cleaning NaN values for "number of open complaints"

# %%
file1['number of open complaints'].value_counts(dropna=False)
# Out:
# 0.0    8160
# 1.0    1145
# NaN     633
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %% [markdown]
# Replacing NaN values with a median value to preserve the data type, as using the mean value will introduce a floating value (0.34) into the set of integrs.

# %%
median_number_of_open_complaints = file1['number of open complaints'].median() 
file1['number of open complaints'] = file1['number of open complaints'].fillna(median_number_of_open_complaints)

# %%
file1['number of open complaints'].value_counts(dropna=False)
# Out:
# 0.0    8793
# 1.0    1145
# 2.0     414
# 3.0     324
# 4.0     166
# 5.0      68
# Name: number of open complaints, dtype: int64

# %% [markdown]
# #### Cleaning NaN values for "vehicle class" column

# %%
file1['vehicle class'].value_counts(dropna=False)
# Out:
# Four-Door Car    5212
# Two-Door Car     2118
# SUV              2012
# NaN               622
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %% [markdown]
# Replacing with the most common value for the obejct.

# %%
# Replacing the value
file1['vehicle class'] = file1['vehicle class'].fillna('Four-Door Car') 
# Checking the outcome
file1['vehicle class'].value_counts(dropna=False)
# Out:
# Four-Door Car    5834
# Two-Door Car     2118
# SUV              2012
# Sports Car        550
# Luxury SUV        208
# Luxury Car        188
# Name: vehicle class, dtype: int64

# %% [markdown]
# #### Cleaning NaN values for "vehicle type" column

# %%
file1['vehicle type'].value_counts(dropna=False)
# Out:
# NaN    5482
# A      5428
# Name: vehicle type, dtype: int64

# %% [markdown]
# Just because over 50% of the data in this column has a NaN value and there is only one further value in the dataset, I made a decision to drop the column.

# %%
file1 = file1.drop(['vehicle type'], axis=1) #Dropping the column

# %% [markdown]
# #### Cleaning NaN values for "vehicle size" column

# %%
file1['vehicle size'].value_counts(dropna=False)
# Out:
# Medsize    7251
# Small      1966
# Large      1071
# NaN         622
# Name: vehicle size, dtype: int64

# %%
file1['vehicle size'] = file1['vehicle size'].fillna('Medsize')

# %% [markdown]
# ### Doublechecking

# %%
file1.isna().sum() #checking if all Nan values are cleared
# Out:
# customer                         0
# state                            0
# customer lifetime value          0
# response                         0
# coverage                         0
# education                        0
# effective to date                0
# employmentstatus                 0
# gender                           0
# income                           0
# location code                    0
# marital status                   0
# monthly premium auto             0
# months since last claim          0
# months since policy inception    0
# number of open complaints        0
# number of policies               0
# policy type                      0
# policy                           0
# renew offer type                 0
# sales channel                    0
# total claim amount               0
# vehicle class                    0
# vehicle size                     0
# dtype: int64

# %% [markdown]
# ### 6. Storing months in a separate column

# %% [markdown]
# Got stuck with the dates! to be finished

# %%
file1.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim          float64
# months since policy inception      int64
# number of open complaints        float64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
file1['effective to date'] = pd.to_datetime(file1['effective to date']) #changed the data type for the date column from object to datetime

# %%
file1.dtypes # double checking the results
# Out:
# customer                                 object
# state                                    object
# customer lifetime value                 float64
# response                                 object
# coverage                                 object
# education                                object
# effective to date                datetime64[ns]
# employmentstatus                         object
# gender                                   object
# income                                    int64
# location code                            object
# marital status                           object
# monthly premium auto                      int64
# months since last claim                 float64
# months since policy inception             int64
# number of open complaints               float64
# number of policies                        int64
# policy type                              object
# policy                                   object
# renew offer type                         object
# ...

# %%
file1['Month'] = file1['effective to date'].dt.month #creating a new column and adding the month value to it

# %%
file1
# Out:
#       customer       state  customer lifetime value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective to date employmentstatus gender  income  ...  \
# ...

# %% [markdown]
# # Round 3

# %% [markdown]
# ### 1. Show dataframe info

# %%
display(file1.head(10))
display(file1.tail()) 
file1.shape
# Out:
#   customer       state  customer lifetime value response  coverage  \
# 0  DK49336     Arizona              4809.216960       No     Basic
# 1  KX64629  California              2228.525238       No     Basic
# 2  LZ68649  Washington             14947.917300       No     Basic
# 3  XL78013      Oregon             22332.439460      Yes  Extended
# 4  QA50777      Oregon              9025.067525       No   Premium
# 5  HO81102  California              4745.181764       No     Basic
# 6  IW72280  California              5035.035257       No     Basic
# 7  IH64929  California              4956.247235       No     Basic
# 8  FM55990  California              5989.773931      Yes   Premium
# 9  QX31376      Oregon             17114.328150       No  Extended
#
#               education effective to date employmentstatus gender  income  \
# 0               College           2/18/11         Employed      M   48029
# 1               College           1/18/11       Unemployed      F       0
# ...

# %% [markdown]
# ### 2. Describe DataFrame.

# %%
file1.describe().T #shows only numerical values
# Out:
#                                  count          mean           std  \
# customer lifetime value        10910.0   8018.241094   6885.081434
# income                         10910.0  37536.284785  30359.195670
# monthly premium auto           10910.0     93.196059     34.442532
# months since last claim        10910.0     15.149071      9.783520
# months since policy inception  10910.0     48.091934     27.940675
# number of open complaints      10910.0      0.361962      0.890134
# number of policies             10910.0      2.979193      2.399359
# total claim amount             10910.0    434.888330    292.180556
#
#                                        min          25%           50%  \
# customer lifetime value        1898.007675  4014.453113   5771.147235
# income                            0.000000     0.000000  33813.500000
# monthly premium auto             61.000000    68.000000     83.000000
# months since last claim           0.000000     7.000000     15.000000
# ...

# %%
file1.describe(include=[np.object]).T
# Out:
# C:\Users\valiu\AppData\Local\Temp\ipykernel_10528\2984122108.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   file1.describe(include=[np.object]).T
#                    count unique            top  freq
# customer           10910   9134        ID89933     7
# state              10910      5     California  4183
# response           10910      2             No  9444
# coverage           10910      3          Basic  6660
# education          10910      5       Bachelor  3272
# effective to date  10910     59        1/10/11   239
# employmentstatus   10910      5       Employed  6789
# gender             10910      2              F  5573
# location code      10910      3       Suburban  6902
# ...

# %% [markdown]
# ### 3. Show a plot of the total number of responses

# %%
import matplotlib.pyplot as plt # importing libraries
import seaborn as sns

# %%
sns.displot(file1['response'], bins=10)
plt.show()

# %% [markdown]
# ### 4. Show a plot of the response rate by the sales channel.

# %% [markdown]
# ### 5. Show a plot of the response rate by the total claim amount
